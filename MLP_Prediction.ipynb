# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn

# Get a target continuous function
# https://medium.com/@nazishjaveed164/create-sinusoidal-plots-using-python-b6cdb7526349
input_val = np.linspace(-10,10,500)
true_val = np.sin(input_val) + np.cos(3*input_val)
# another function
#true_val = input_val**2

# convert to tensors, shape (500, 1)
# https://medium.com/@kansara.anjul/function-approximation-with-artificial-neural-networks-in-pytorch-d94d7e2282cf
x_input = torch.tensor(input_val, dtype=torch.float32).unsqueeze(1)
y_true  = torch.tensor(true_val,  dtype=torch.float32).unsqueeze(1)



# Define Model Architecture
# The input layer, hidden layer, amount of neurons, activation function(ReLu or Tanh - introduces non-linearity into model) and output layer

# https://docs.pytorch.org/docs/stable/generated/torch.nn.Sequential.html
input_dim = 1 # number of features in 1 input vector x
output_dim = 1 # number of features in 1 output vector y

neurons = 150
epoch_amount = 3000
learning_rate = 0.005 # default in the documentation is 1e-3 for SGD

# Build the model
# https://github.com/timothylimyl/UAT/blob/master/approx_pytorch.py
# https://towardsdatascience.com/understand-universal-approximation-theorem-with-code-774dcef55731/
# https://docs.pytorch.org/docs/stable/generated/torch.nn.Tanh.html
# https://docs.pytorch.org/docs/stable/generated/torch.nn.ReLU.html
# https://www.geeksforgeeks.org/deep-learning/understanding-the-forward-function-output-in-pytorch/
# code was mostly inspired and taken from github link to timothylimyl's code.
# parameters were mostly decided by tweaking around and seeing what had the best output


# Create training set

# Train the model

# Compare results with different layers(etc. Linear Regression, number of neurons)


# plotting original graph alone
plt.plot(x_input,y_true, label='Actual Function')
plt.legend()
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Actual Function')
plt.show()
